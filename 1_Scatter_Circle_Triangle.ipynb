# %% [markdown]
# # Bokeh_Sca

# %%
from bokeh.plotting import figure
from bokeh.io import show, output_notebook
from bokeh.models import ColumnDataSource

data = {'x_values': [1, 2, 3, 4, 5],
        'y_values': [6, 7, 2, 3, 6]}

source = ColumnDataSource(data = data)  #Maps names of columns to sequences or arrays.

p = figure()
p.circle(x='x_values', y='y_values', source=source)


output_notebook()                    # Set to output the plot in the notebook

show(p)                               # Show the plot
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1770">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="fbb813d9-0680-46be-a83e-7475eee42541" data-root-id="1733"></div>

# %%
p = figure()
p.triangle(x='x_values', y='y_values', source=source, alpha = 0.6, size = 12)

# Set to output the plot in the notebook
output_notebook()
# Show the plot
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2181">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="216cf4ad-c1a2-4109-ae57-54a68f5d49d4" data-root-id="2144"></div>
